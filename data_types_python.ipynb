# %% [markdown]
# # data types in python
# 1. different vatype of values assigned to variables
# 2. basically 3 data types in python
# 3. int (integer) - numerical values like 1,2,3,4...n
# 4. str(string) - charecters examples "abcd", ghjk" , qwert"
# 5. flot(decimals) - nuermical with - with decimal - 10.25, 100.25,125.35...

# %%
name="vikas"
age=25
salary=100023.25
data="123"
print(name)
print(age)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# vikas
# 25
# 100023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatenation
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1="python"
n2="programming"
print(n1+n2)
# Out:
# pythonprogramming

# %%
a=100
b="300"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 a=100
#       2 b="300"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
