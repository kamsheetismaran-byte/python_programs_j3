# %%
# operators in python 

## 6 types of operators in python 
1. arithematic operators
2. assignment operators
3. comparision operators
4. logical operators
5. membership operators
6. identitly operators

# %%
# arthematic operators - +,-,=,*,/,//,%
a=10
b=20
c=20
d=30
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(d//a)
print(d%a)
# Out:
# 30
# 0
# 600
# 3.0
# 3
# 0

# %%
# arthematic operators - +,-,=,*,/,//,%
a=100
a+=50
print(a)
# Out:
# 150

# %%
b=-200
b-=400
print(b)
# Out:
# -600

# %%
c=50
c*=100
print(c)
# Out:
# 5000

# %%
# comprassion operators ->,<,>=,<=,==,!=
a=10
b=20
c=20
d=30
print(a>b)
print(b==c)
print(b>c)
print(b!=c)
print(b>=a)
print(b<=a)
# Out:
# False
# True
# False
# False
# True
# False

# %%
# logical operator - and , or, not
"""
and - both conditions is True then Rrsults is True , rest cast it False 
or - either one condition is True the resultnis True , rest case result is False
and truth Table 
T T = T
F T = F
T F = F
F F = F
or truth table
T T = T
T F = T
F T = T
F F = T
"""
a=10
b=20
c=20
d=30
print(a>b and b==c)
print(a<b and c==b)
print(a>b or b==c)
print(not a>b and b==c)
# Out:
# False
# True
# True
# True

# %%
# membership operator - in ,not in
# validating members are present in that sequenece or group
names=["vikas","shivaji","sidh","chndra"]
print("vikas" in names )
print("shivaji"not in names)
print("Vikas" not in names)
print("vikas" in names)
# Out:
# True
# False
# True
# True

# %%
# identity operators - is ,is not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2655547193168
# 2655547192208

# %%
a=10
b=10
print(a is b)
print(id(a))
print(id(b))
# Out:
# True
# 140732138747080
# 140732138747080
