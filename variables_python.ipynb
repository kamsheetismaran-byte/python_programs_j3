# %% [markdown]
# # variables in python
# variable is memory allocation to a value
# examples are name="shivaji",age=26,salary=10000.55
# # key point to define variable
# 1. do not start with digit while creating variables
# 2. does not allow special charecters in a variable
# 3. do not use keyboard as avariable

# %%
name="vikas"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
# Out:
# vikas
# 26
# 10000.55

# %%
1name="vikas"
print(1name)
# Out:
#   Cell In[2], line 1
#     1name="vikas"
#     ^
# SyntaxError: invalid decimal literal

# %%
name@="shivaji"
print(name)

# %%
for2 = "vikas"
print(for2)
# Out:
# vikas
